# %%
# !jupyter nbconvert --to script streamlit-dashboard.ipynb
# Out:
# [NbConvertApp] Converting notebook streamlit-dashboard.ipynb to script
# [NbConvertApp] Writing 1281 bytes to streamlit-dashboard.py
